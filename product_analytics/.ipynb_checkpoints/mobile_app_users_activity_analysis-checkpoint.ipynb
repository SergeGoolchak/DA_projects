# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузка-данных-и-подготовка-к-анализу" data-toc-modified-id="Загрузка-данных-и-подготовка-к-анализу-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузка данных и подготовка к анализу</a></span><ul class="toc-item"><li><span><a href="#Импорт-библиотек-и-чтение-данных" data-toc-modified-id="Импорт-библиотек-и-чтение-данных-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Импорт библиотек и чтение данных</a></span></li><li><span><a href="#Подготовка-данных-к-анализу" data-toc-modified-id="Подготовка-данных-к-анализу-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Подготовка данных к анализу</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Определение-функций-для-исследования-и-анализа-данных" data-toc-modified-id="Определение-функций-для-исследования-и-анализа-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Определение функций для исследования и анализа данных</a></span><ul class="toc-item"><li><span><a href="#Функции-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии" data-toc-modified-id="Функции-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Функции для расчета и анализа LTV, ROI, удержания и конверсии</a></span></li><li><span><a href="#Функции-для-визуализации-метрик" data-toc-modified-id="Функции-для-визуализации-метрик-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Функции для визуализации метрик</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Исследование" data-toc-modified-id="Исследование-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Исследование</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Маркетинг" data-toc-modified-id="Маркетинг-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Маркетинг</a></span></li><li><span><a href="#Расчет-и-анализ-бизнес-метрик" data-toc-modified-id="Расчет-и-анализ-бизнес-метрик-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Расчет и анализ бизнес-метрик</a></span><ul class="toc-item"><li><span><a href="#Анализ-общей-окупаемости-рекламы" data-toc-modified-id="Анализ-общей-окупаемости-рекламы-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Анализ общей окупаемости рекламы</a></span></li><li><span><a href="#Анализ-окупаемости-рекламы-с-разбивкой-по-устройствам" data-toc-modified-id="Анализ-окупаемости-рекламы-с-разбивкой-по-устройствам-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Анализ окупаемости рекламы с разбивкой по устройствам</a></span></li><li><span><a href="#Анализ-окупаемости-рекламы-с-разбивкой-по-странам" data-toc-modified-id="Анализ-окупаемости-рекламы-с-разбивкой-по-странам-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Анализ окупаемости рекламы с разбивкой по странам</a></span></li><li><span><a href="#Анализ-окупаемости-рекламы-с-разбивкой-по-рекламным-каналам" data-toc-modified-id="Анализ-окупаемости-рекламы-с-разбивкой-по-рекламным-каналам-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Анализ окупаемости рекламы с разбивкой по рекламным каналам</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></div>

# %% [markdown]
# ## Загрузка данных и подготовка к анализу

# %% [markdown]
# ### Импорт библиотек и чтение данных

# %% [markdown]
# Импортируем библиотеки для работы.

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import matplotlib.pyplot as plt

# %% [markdown]
# Запишем в переменную path локальный путь к файлу с данными.

# %%
path = '/Users/segagoose/Documents/YandexPracticum/бизнес метрики/project'

# %% [markdown]
# Прочитаем файлы с данными и запишем их в переменные `visits`, `orders`, `ads_cost`.

# %%
try:
    visits = pd.read_csv(path + '/visits_info_short.csv')
    
    orders = pd.read_csv(path + '/orders_info_short.csv')
    
    ads_cost = pd.read_csv(path + '/costs_info_short.csv')
    
except:
    visits = pd.read_csv('/datasets/visits_info_short.csv')
    
    orders = pd.read_csv('/datasets/orders_info_short.csv')
    
    ads_cost = pd.read_csv('/datasets/costs_info_short.csv')

# %% [markdown]
# Выведем на экран полученные датасеты.

# %%
visits.head()
# Out:
#         User Id         Region   Device  Channel        Session Start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
#            Session End
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# 4  2019-05-01 03:57:40

# %%
orders.head()
# Out:
#         User Id             Event Dt  Revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99

# %%
ads_cost.head()
# Out:
#            dt   Channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# 2  2019-05-03  FaceBoom   85.8
# 3  2019-05-04  FaceBoom  136.4
# 4  2019-05-05  FaceBoom  122.1

# %%
for data in [visits, orders, ads_cost]:
    data.info()
    print()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   User Id        309901 non-null  int64
#  1   Region         309901 non-null  object
#  2   Device         309901 non-null  object
#  3   Channel        309901 non-null  object
#  4   Session Start  309901 non-null  object
#  5   Session End    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   User Id   40212 non-null  int64
#  1   Event Dt  40212 non-null  object
#  2   Revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# ...

# %% [markdown]
# Изучив полученные таблицы, мы видим отсутсвие пропусков в данных - это хорошо.
# Однако необходимо преобразовать названия столбцов согласно стандартам, а типы значений в колонках с датой и временем привести к типу datetime. <br>
# А также требуется проверить данные на наличие дубликатов.

# %% [markdown]
# ### Подготовка данных к анализу

# %% [markdown]
# Переименуем названия столбцов в переменной `visits`.

# %%
visits.columns = ['user_id', 'region', 'device', 'channel', 'session_start',
       'session_end']

# %% [markdown]
# Выведем результат на экран.

# %%
visits.head()
# Out:
#         user_id         region   device  channel        session_start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
#            session_end
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# 4  2019-05-01 03:57:40

# %% [markdown]
# Повторим операцию с `orders`.

# %%
orders.columns = ['user_id', 'event_dt', 'revenue']

# %%
orders.head()
# Out:
#         user_id             event_dt  revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99

# %% [markdown]
# И с `ads_cost`.

# %%
ads_cost.columns = ['dt', 'channel', 'costs']

# %%
ads_cost.head()
# Out:
#            dt   channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# 2  2019-05-03  FaceBoom   85.8
# 3  2019-05-04  FaceBoom  136.4
# 4  2019-05-05  FaceBoom  122.1

# %% [markdown]
# Изучим, есть ли дубликаты в датасетах.

# %%
for column in ['region', 'device', 'channel']:
    display(visits[column].value_counts())

ads_cost['channel'].value_counts()
# Out:
# United States    207327
# UK                36419
# France            35396
# Germany           30759
# Name: region, dtype: int64
# iPhone     112603
# Android     72590
# PC          62686
# Mac         62022
# Name: device, dtype: int64
# organic               107760
# TipTop                 54794
# FaceBoom               49022
# WahooNetBanner         20465
# LeapBob                17013
# OppleCreativeMedia     16794
# RocketSuperAds         12724
# YRabbit                 9053
# MediaTornado            8878
# AdNonSense              6891
# lambdaMediaAds          6507
# Name: channel, dtype: int64
# FaceBoom              180
# MediaTornado          180
# RocketSuperAds        180
# TipTop                180
# YRabbit               180
# AdNonSense            180
# LeapBob               180
# OppleCreativeMedia    180
# WahooNetBanner        180
# lambdaMediaAds        180
# Name: channel, dtype: int64

# %%
for table in [visits, orders, ads_cost]:
    print(table[table.duplicated() == True])
# Out:
# Empty DataFrame
# Columns: [user_id, region, device, channel, session_start, session_end]
# Index: []
# Empty DataFrame
# Columns: [user_id, event_dt, revenue]
# Index: []
# Empty DataFrame
# Columns: [dt, channel, costs]
# Index: []

# %% [markdown]
# Дубликаты отсутсвуют.

# %% [markdown]
# Заменим типы данных в столбцах **session_start** и **session_end** таблицы `visits`, а также в **event_dt** таблицы `orders` и **dt** таблицы `ads_cost`.

# %%
visits['session_start'] = pd.to_datetime(visits['session_start'])
visits['session_end'] = pd.to_datetime(visits['session_end'])

orders['event_dt'] = pd.to_datetime(orders['event_dt'])

ads_cost['dt'] = pd.to_datetime(ads_cost['dt']).dt.date

# %% [markdown]
# ### Вывод

# %% [markdown]
# В этой главе мы прочитали и изучили получение данные по визитам пользователей приложения Procrastinate Pro+, их покупкам в данном приложении, а также по тратам на рекламу для привлечения новых пользователей.
# В полученных данных отсутвуют дубликаты и пропуски. Мы привели названия столбцов к принятым стандартам и преобразовали к типу datetime данные о начале(`session_start`), конце сессий(`session_end`), к типу date дату рекламы(`dt`), а также о дате и и времени покупки(`event_dt`). <br>
# Датасеты готовы к проведению анализа.

# %% [markdown]
# ## Определение функций для исследования и анализа данных

# %% [markdown]
# ### Функции для расчета и анализа LTV, ROI, удержания и конверсии

# %% [markdown]
# Зададим функцию для создания пользовательских профилей.

# %%
def get_profiles(sessions, orders, ad_costs):

    # находим параметры первых посещений
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %% [markdown]
# Далее зададим функцию для расчета удержания.

# %%
def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# Функция для расчета конверсии.

# %%
def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# Далее функция для расчета LTV и ROI.

# %%
def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# ### Функции для визуализации метрик

# %% [markdown]
# Функция для сглаживания данных.

# %%
def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %% [markdown]
# Определим функцию для визуализации удержания.

# %%
def plot_retention(retention, retention_history, horizon, window=7):

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1, figsize=(15, 10)
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2, figsize=(15, 10)
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3, figsize=(15, 10))
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4, figsize=(15, 10))
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# Далее функция для визуализации конверсии.

# %%
def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# Теперь зададим функцию для визуализации LTV и ROI.

# %%
def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1, figsize=(20, 10))
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2, figsize=(20, 10))
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3, figsize=(20, 10))
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4, figsize=(20, 10))
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5, figsize=(20, 10))
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Вывод

# %% [markdown]
# Мы определили в этой главе функции, которые помогут нам провести исследовательский анализ данных, рассчитать и визуализировать основные метрики. Можно приступать к следующему этапу.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Исследование

# %% [markdown]
# Используем функцию get_profiles для создания профилей пользователей нашего приложения и результат на экран.

# %%
profiles = get_profiles(visits, orders, ads_cost)

profiles.head()
# Out:
#     user_id            first_ts     channel  device         region  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True          1.088172
# 1  2019-07-09 2019-07-01  False          1.107237
# 2  2019-10-01 2019-10-01  False          0.000000
# 3  2019-08-22 2019-08-01  False          0.988235
# 4  2019-10-02 2019-10-01  False          0.230769

# %% [markdown]
# При изучении наличия дубликатов данных в пункте 2.2, мы выявили, что:
# - пользователи приложения Procrastinate Pro+ проживают в странах: United States, France, Germany и UK;
# - следующие устройства используются для запуска приложения: Mac, iPhone, PC, Android;
# - привлекали пользователей с помощью каналов: FaceBoom, AdNonSense, YRabbit, MediaTornado, RocketSuperAds, LeapBob, TipTop, WahooNetBanner, OppleCreativeMedia, lambdaMediaAds.<br>

# %% [markdown]
# Найдем минимальную и максимальную дату привлечения пользователей.

# %%
dd = profiles.sort_values(by='dt').groupby('user_id').agg({'dt': ['min', 'max']})

# %%
min_first_ts = profiles['dt'].min()

print(min_first_ts)
# Out:
# 2019-05-01

# %%
max_first_ts = profiles['dt'].max()

print(max_first_ts)
# Out:
# 2019-10-27

# %% [markdown]
# По полученным данным первый привлеченный с помощью рекламы пользователь воспользовался приложением 01.05.2019 г., а последнее привлечение произошло 27.10.2019 г.

# %% [markdown]
# Изучим какие страны дают больше всего платящих пользователей.

# %%
payers_stat = profiles.pivot_table(
    index='region', 
    columns='payer', 
    values='user_id', 
    aggfunc='nunique'
)

#переименуем столбцы
payers_stat.columns = ['not_payers', 'payers']

# %% [markdown]
# Добавим данные по общему количеству пользователей.

# %%
payers_stat['all_users'] = payers_stat['not_payers'] + payers_stat['payers']

# %% [markdown]
# Вичислим соотнешение платящих пользователей к общему количеству.

# %%
payers_stat['cr'] = (payers_stat['payers'] / payers_stat['all_users'] * 100).round(2)

# %%
payers_stat.sort_values(by='payers', ascending=False)
# Out:
#                not_payers  payers  all_users    cr
# region
# United States       93100    6902     100002  6.90
# UK                  16875     700      17575  3.98
# France              16787     663      17450  3.80
# Germany             14365     616      14981  4.11

# %% [markdown]
# Отобразим полученные данные на графике.

# %%
payers_stat.reset_index().plot(
    x='region', 
    y='payers', 
    kind="barh", 
    figsize=(15,5),
    title='Количество платящих пользователей в разрезе стран проживания'
)

plt.show()

# %% [markdown]
# Мы можем сделать вывод о том, что больше всего пользователей из United States и данные пользователи имеют самый высокий процент по конверсии в "платящих" пользователей 6.90%, тогда как меньше всего пользователей приложения из Germany при этом по соотношению они занимают вторую строчку с почти 4.11%. Самая низкая конвертация пользователей из France c 3.8%.

# %% [markdown]
# Изучим данные, сколько пользователей конвертируется в платящих в разрезе используемых устройств.

# %% [markdown]
# Сгруппируем данные по устройствам.

# %%
device_stat = (
    profiles.query('payer == True')
    .groupby('device')
    .agg({'user_id': 'nunique'})
    .sort_values(by='user_id', ascending=False)
)

# %% [markdown]
# Добавим к таблице количество всех пользователей в разрезе устройств.

# %%
device_stat = device_stat.merge(
    profiles.groupby('device')
    .agg({'user_id': 'nunique'})
    .sort_values(by='user_id', ascending=False),
    on='device'
)

# %% [markdown]
# Переименуем столбцы.

# %%
device_stat.columns = ['payers', 'all_users']

# %% [markdown]
# Добавим данные по соотношению платящих пользователей ко общему количеству пользователей устройства в процентах.

# %%
device_stat['cr'] = (device_stat['payers'] / device_stat['all_users'] * 100).round(2)

# %% [markdown]
# Выведем на экран.

# %%
device_stat
# Out:
#          payers  all_users    cr
# device
# iPhone     3382      54479  6.21
# Android    2050      35032  5.85
# Mac        1912      30042  6.36
# PC         1537      30455  5.05

# %% [markdown]
# Визуализируем полученные данные.

# %%
device_stat.reset_index().plot(
    x='device', 
    y='payers', 
    kind="barh", 
    figsize=(15,5),
    title='Количество платящих пользователей в разрезе используемых устройств'
)

plt.show()

# %% [markdown]
# Большинство платящей аудитории пользуются продукцией Apple, а именно пользователи Iphone в количестве 3382 человек и пользователи Mac в количестве 1912 человек. Пользователи Mac занимают 3 место по количеству платящих пользователей, однако они на 1 месте по соотношению платящих ко всем пользователям данного устройства. Меньше всего конвертируются в платящих пользователи РС, всего 1537 человек и самая низкая конвертация в 5.05%. Пользователи Android с количеством 2050 платящих пользователей заняли вторую строку.

# %% [markdown]
# Изучим данные по количеству платящих пользователей в разрезе каналов привелечения.

# %%
channel_stat = profiles.pivot_table(
    index='channel', 
    columns='payer',
    values='user_id',
    aggfunc='nunique'
)

# %% [markdown]
# Переименуем столбцы.

# %%
channel_stat.columns = ['not_payers', 'payers']

# %% [markdown]
# Добавим данные по общему количеству пользователей.

# %%
channel_stat['all_users'] = channel_stat['not_payers'] + channel_stat['payers']

# %% [markdown]
# Расчитаем конверсию.

# %%
channel_stat['cr'] = (channel_stat['payers'] / channel_stat['all_users'] * 100).round(2)

# %% [markdown]
# Отсортируем таблицу по количеству платящих пользователей и выведем ее на экран.

# %%
channel_stat = channel_stat.sort_values(by='payers', ascending=False)

# %%
channel_stat
# Out:
#                     not_payers  payers  all_users     cr
# channel
# FaceBoom                 25587    3557      29144  12.20
# TipTop                   17683    1878      19561   9.60
# organic                  55279    1160      56439   2.06
# WahooNetBanner            8100     453       8553   5.30
# AdNonSense                3440     440       3880  11.34
# RocketSuperAds            4096     352       4448   7.91
# LeapBob                   8291     262       8553   3.06
# OppleCreativeMedia        8372     233       8605   2.71
# lambdaMediaAds            1924     225       2149  10.47
# YRabbit                   4147     165       4312   3.83
# MediaTornado              4208     156       4364   3.57

# %% [markdown]
# Визуализируем данные.

# %%
channel_stat.reset_index().plot(
    x='channel', 
    y='payers', 
    kind="barh", 
    figsize=(15,5),
    title='Количество платящих пользователей в разрезе каналов привлечения'
)

plt.show()

# %% [markdown]
# Видно как особенно выделяются два канала привлечения пользоватлей FaceBoom и TipTop, они приносят в разы больше пользователей чем остальные каналы. Восемь других других каналов не имеют такого сильного различия в количестве привлекаемых пользователей.
# Бесплатные пользователи из канала organic конвертируются в платящих хуже всего, при этом по количеству платящих пользователей они занимают 3 место после пользователец с каналов FaceBoom и TipTop. Это очень хорошо, ведь на их привлечение компания не тратит денежных средств.

# %% [markdown]
# ### Вывод

# %% [markdown]
# Проанализировав профили наших пользователей, мы выявили:
# - по полученным данным первый привлеченный с помощью рекламы пользователь воспользовался приложением 01.05.2019 г., а последнее привлечение произошло 27.10.2019 г;
# - пользователи приложения Procrastinate Pro+ проживают в странах: United States, France, Germany и UK;
# - следующие устройства используются для запуска приложения: Mac, iPhone, PC, Android;
# - привлекали пользователей с помощью каналов: FaceBoom, AdNonSense, YRabbit, MediaTornado, RocketSuperAds, LeapBob, TipTop, WahooNetBanner, OppleCreativeMedia, lambdaMediaAds;
# -  больше всего пользователей из United States и данные пользователи имеют самый высокий процент по конверсии в "платящих" пользователей 6.90%, тогда как меньше всего пользователей приложения из Germany при этом по соотношению они занимают вторую строчку с почти 4.11%. Самая низкая конвертация пользователей из France c 3.8%;
# - большинство платящей аудитории пользуются продукцией Apple, а именно пользователи Iphone в количестве 3382 человек и пользователи Mac в количестве 1912 человек. Пользователи Mac занимают 3 место по количеству платящих пользователей, однако они на 1 месте по соотношению платящих ко всем пользователям данного устройства. Меньше всего конвертируются в платящих пользователи РС, всего 1537 человек и самая низкая конвертация в 5.05%. Пользователи Android с количеством 2050 платящих пользователей заняли вторую строку;
# - выделяются два канала привлечения пользоватлей FaceBoom и TipTop, они приносят в разы больше пользователей чем остальные каналы. Восемь других других каналов не имеют такого сильного различия в количестве привлекаемых пользователей;
# - бесплатные пользователи из канала organic конвертируются в платящих хуже всего - 2.06%, при этом по количеству платящих пользователей они занимают 3 место после пользователец с каналов FaceBoom и TipTop. Это очень хорошо, ведь на их привлечение компания не тратит денежных средств.

# %% [markdown]
# ## Маркетинг

# %% [markdown]
# Отфильтруем данные в таблице, исключив пользователей, которые пришли самостоятельно, без участия рекламы. Ведь наша цель изучить насколько действенна и выгодна реклама компании.

# %%
filtered_profiles = profiles.query('channel != "organic"')

# %% [markdown]
# Вычислим сколько всего потратила компания на рекламу для привлечения новых пользователей за период с 01.05.2019 г. по 27.10.2019 г.

# %%
total_expenses = ads_cost['costs'].sum().round(2)

total_expenses
# Out:
# 105497.3

# %% [markdown]
# За весь период времени было потрачено 105 497.3 у.е.
#
# Изучим сколько пришлось затрат на каждый рекламный канал.

# %%
channel_costs = (
    ads_cost.groupby('channel')
    .agg({'costs':'sum'})
    .round(2)
    .sort_values(by='costs', ascending=False)
)

channel_costs
# Out:
#                        costs
# channel
# TipTop              54751.30
# FaceBoom            32445.60
# WahooNetBanner       5151.00
# AdNonSense           3911.25
# OppleCreativeMedia   2151.25
# RocketSuperAds       1833.00
# LeapBob              1797.60
# lambdaMediaAds       1557.60
# MediaTornado          954.48
# YRabbit               944.22

# %% [markdown]
# Визуализируем полученные данные.

# %%
channel_costs.plot(
    kind='bar', 
    grid=True, 
    title='Затраты на каналы привлечения',
    figsize=(15,5)
)

plt.show()

# %% [markdown]
# Самые большие вложения приходятся на рекламу в TipTop и FaceBoom в размере 54 751.30 у.е. и 32 445.60 у.е. соответственно. На все остальные каналы приходится в разы меньше вложений, а самая минимальное на канал YRabbit 944.22 у.е.

# %% [markdown]
# Изучим данные по ежедневным расходам на рекламу.

# %%
days_expenses = (
    ads_cost.groupby('dt')
    .agg({'costs':'sum'})
    .round(2)
    .sort_values(by='dt')
)

days_expenses.head()
# Out:
#              costs
# dt
# 2019-05-01  304.82
# 2019-05-02  230.84
# 2019-05-03  263.07
# 2019-05-04  337.00
# 2019-05-05  319.90

# %% [markdown]
# Для наглядности построим график по данным.

# %%
filter_data(days_expenses, 7).plot(
    kind='line', 
    grid=True, 
    title='Уровень ежедневных вложений в рекламу',
    figsize=(15,5)
)

plt.show()

# %% [markdown]
# На графике отчетливо виден рост затрат от месяца к месяцу, а также после каждого роста вложений в рекламу идет спад, скорее всего после очередного увелечения рекламных затрат, компания их снижает и наблюдает на эффект от этих вложений, а затем продолжает вложения, возможно, уже в другие каналы.

# %% [markdown]
# Расчитаем среднюю стоимость привлечения одного покупателя.

# %%
round(filtered_profiles['acquisition_cost'].mean(), 2)
# Out:
# 1.13

# %% [markdown]
# А теперь изучим сколько в среднем стоило привлечение одного покупателя из каждого источника.

# %%
cac = (
    filtered_profiles.groupby('channel')
    .agg({'acquisition_cost':'mean'})
    .round(2)
    .sort_values(by='acquisition_cost',ascending=False)
)

cac
# Out:
#                     acquisition_cost
# channel
# TipTop                          2.80
# FaceBoom                        1.11
# AdNonSense                      1.01
# lambdaMediaAds                  0.72
# WahooNetBanner                  0.60
# RocketSuperAds                  0.41
# OppleCreativeMedia              0.25
# MediaTornado                    0.22
# YRabbit                         0.22
# LeapBob                         0.21

# %% [markdown]
# Визуализируем данные.

# %%
cac.plot(
    kind='bar', 
    grid=True, 
    title='Cредняя стоимость рекламных затрат на одного пользователя в разрезе каналов привлечения',
    figsize=(15,5)
)

plt.show()

# %% [markdown]
# Самое дорогое привлечение новых клиентов получается через рекламный источник TipTop - 2.8 у.е.. FaceBoom, в который также очень много вкладывается средств, по стоимости привлечения одного клиента не так сильно выделятся от остальных - 1.1 у.е. Самое дешевое привлечение клиентов получается через каналы OppleCreativeMedia,
# MediaTornado, YRabbit и LeapBob - от 0.25 до 0.21 у.е.

# %% [markdown]
# **Вывод:**<br>
#
# По данным за период с 01.05.2019 г. по 27.10.2019 г. компания, для привлечения новых пользователей, вложила в рекламу 105 497.3 у.е.. Самые большие вложения в рекламные каналы TipTop и FaceBoom в размере 54 751.30 у.е. и 32 445.60 у.е. соответственно. TipTop также является и самым дорогим каналом для привлечения одного нового пользователя. А самыми дешевыми источниками оказались OppleCreativeMedia, MediaTornado, YRabbit и LeapBob с затратами на одного пользователя от 0.25 до 0.21 у.е..<br>
# Засчет дорогих каналов привлечения, а именно TipTop и FaceBoom, средняя стоимость привлечения одного покупателя выросла до 1.13 у.е., это оказывает значительное воздействие на оккупаемость рекламы.<br>
# Виден рост затрат от месяца к месяцу, а также после каждого роста вложений в рекламу идет спад, скорее всего после очередного увелечения рекламных затрат, компания их снижает и наблюдает на эффект от этих вложений, а затем продолжает вложения, возможно, уже в другие каналы.<br>
# Насколько выгодны вложения в данные рекламные источники и насколько целесообразно компания распределяет свой рекламный бюджет мы узнаем расчитав и проанализировав бизнес-метрики в следующей главе.

# %% [markdown]
# ## Расчет и анализ бизнес-метрик

# %% [markdown]
# ### Анализ общей окупаемости рекламы

# %% [markdown]
# Зададим момент и горизонт анализа данных.

# %%
observation_date = datetime(2019, 11, 1).date()

horizon_days = 14

# %% [markdown]
# Теперь расчитаем общие показатели LTV и ROI для изучения общей окупаемости рекламы.

# %%
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    filtered_profiles, 
    orders, 
    observation_date, 
    horizon_days
)

plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, 14)

# %% [markdown]
# По графикам можем сделать вывод, что реклама не окупается. В мае и июне она еще была прибыльна, но в связи с тем, что САС постоянно рос, ROI c каждым месяцем снижался. LTV пользователей на 14 день стабильный из месяца в месяц, значит покупательская способность клиентов не снижалась.<br><br>
#
# Рассмотрим данные показатели в разрезе устройств, стран и рекламных каналов, постараемся выяснить, что могло повлиять на такие результаты.

# %% [markdown]
# ### Анализ окупаемости рекламы с разбивкой по устройствам

# %% [markdown]
# Зададим в параметры для анализа - устройства, чтобы изучить данные в их разрезе.

# %%
dimensions = ['device']

# %% [markdown]
# Соберем данные и визуализируем их.

# %%
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    filtered_profiles, 
    orders, 
    observation_date, 
    horizon_days,
    dimensions
)

plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, 14)

# %% [markdown]
# Окупаемость 12 дня видна только у пользователей PC, это связано с тем, что у этой когорты самые низние показатели стоимости привлечения пользователей. Однако по динамике ROI все также наблюдается постепенное снижение данного показателя. LTV стабильный, явных отклонений не наблюдается.<br><br>
# Изучим конверсию пользователей.

# %%
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days, 14)

# %% [markdown]
# По конверсии наблюдается не большой рост в мае и июне, затем он выравнивается. Выделяются на фоне остальных когорт - пользователи РС с самыми низкими показателями конверсии.<br>
#
# Но дело точно не в ней. Изучим данные по удержанию клиентов.

# %%
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days, 14)

# %% [markdown]
# Удержание платящих пользователей РС несколько выше остальных устройств, но это не значительное отличие, и точно не оказывает сильного воздействия на окупаемость рекламы. Показатели всех когорт стабильны и показывают примерно одинаковый уровень.<br>
#
# Изучим данные с разбивкой по странам.

# %% [markdown]
# ### Анализ окупаемости рекламы с разбивкой по странам

# %% [markdown]
# Установим параметры "по регионам".

# %%
dimensions = ['region']

# %% [markdown]
# Расчитаем показетели LTV и ROI. И визуализируем их.

# %%
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    filtered_profiles, 
    orders, 
    observation_date, 
    horizon_days,
    dimensions
)

plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, 14)

# %% [markdown]
# А вот мы и увидели первые признаки убыточности рекламы. Стоимость привлечения пользователей из стран Germany, UK и France снижаются в июне и затем стабильно идут на низком уровне, а вот в пользователей из United States на протяжении всего периода изучения затраты на привлечение увеличиваются. По покателям LTV пользователи из United States приносят больше выручки, однако этого не достаточно и на протяжении всего периода они убыточны. Пользователи всех остальных стран окупается постоянно и точку безубыточности проходят на 5-7 день.<br>
#
# Изучим показатели конверсии.

# %%
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days, 14)

# %% [markdown]
# Пользователи из United States конвертируются в платящих лучше остальных, значит дело точно не в этом показателе.
#
# Изучим коэфициент удержания.

# %%
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days, 14)

# %% [markdown]
# Удержание американиских пользователей ниже аналогичного показателя пользователей остальных стран. Оно стабильно низкое для 14-го дня в районе 10%.<br>
#
# Изучим данные в разрезе рекламных каналов.

# %% [markdown]
# ### Анализ окупаемости рекламы с разбивкой по рекламным каналам

# %% [markdown]
# Зададим параметры для анализа данных по рекламным источникам.

# %%
dimensions = ['channel']

# %% [markdown]
# Произведем расчет LTV и ROI и представим данные на графиках.

# %%
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    filtered_profiles, 
    orders, 
    observation_date, 
    horizon_days,
    dimensions
)

plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, 14)

# %% [markdown]
# Для наглядности выведем таблицы с полученными данными.

# %%
ltv_grouped
# Out:
#                     cohort_size       0.0       1.0       2.0       3.0  \
# channel
# AdNonSense                 3702  0.505030  0.589149  0.644417  0.683509
# FaceBoom                  27544  0.585703  0.660825  0.700722  0.728842
# LeapBob                    8103  0.107048  0.155702  0.205583  0.235391
# MediaTornado               4167  0.137485  0.191615  0.246943  0.293667
# OppleCreativeMedia         8139  0.097239  0.131578  0.171686  0.206636
# RocketSuperAds             4251  0.207570  0.318640  0.396114  0.455980
# TipTop                    18498  0.343550  0.497389  0.624141  0.739834
# WahooNetBanner             8082  0.191302  0.291477  0.378921  0.443754
# YRabbit                    4102  0.163301  0.213423  0.256000  0.303932
# lambdaMediaAds             2056  0.460268  0.645302  0.778789  0.905540
#
#                          4.0       5.0       6.0       7.0       8.0  \
# channel
# AdNonSense          0.706694  0.732582  0.754149  0.767628  0.789203
# ...

# %%
roi_grouped
# Out:
#                     cohort_size       cac       0.0       1.0       2.0  \
# channel
# AdNonSense                 3702  1.008023  0.501010  0.584460  0.639288
# FaceBoom                  27544  1.113419  0.526040  0.593510  0.629343
# LeapBob                    8103  0.210000  0.509752  0.741436  0.978967
# MediaTornado               4167  0.219035  0.627684  0.874814  1.127410
# OppleCreativeMedia         8139  0.249908  0.389100  0.526504  0.686996
# RocketSuperAds             4251  0.417431  0.497256  0.763336  0.948932
# TipTop                    18498  2.757774  0.124575  0.180359  0.226321
# WahooNetBanner             8082  0.601856  0.317853  0.484298  0.629588
# YRabbit                    4102  0.217087  0.752238  0.983122  1.179250
# lambdaMediaAds             2056  0.727237  0.632899  0.887333  1.070887
#
#                          3.0       4.0       5.0       6.0       7.0  \
# channel
# AdNonSense          0.678069  0.701069  0.726752  0.748147  0.761519
# ...

# %% [markdown]
# Лидирующие позиции по выручке занимают два канала lambdaMediaAds и TipTop, не плохие показатели у каналов RocketSuperAds, AdNonSense, WahooNetBanner и FaceBoom. При этом, если обратить внимание на окупаемость каналов TipTop, FaceBoom и AdNonSense, то они не окупаются вовсе, остальные приносят прибыль. Изучив динамику стоимости привлечения стоимости мы видим выделяющийся постоянный рост затрат на канал TipTop, судя по предыдущим показателям неоправданно высокий рост, во все остальные каналы вложения на стабильном уровне.
#
# Изучим конверсию пользователей по каналам привлечения.

# %%
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    filtered_profiles, orders, observation_date, horizon_days, dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days, 14)

# %%
conversion_grouped
# Out:
#                     cohort_size       0.0       1.0       2.0       3.0  \
# channel
# AdNonSense                 3702  0.086980  0.094003  0.096704  0.100486
# FaceBoom                  27544  0.102091  0.109134  0.111494  0.113346
# LeapBob                    8103  0.016660  0.020610  0.024065  0.025052
# MediaTornado               4167  0.023278  0.027358  0.028078  0.029998
# OppleCreativeMedia         8139  0.017324  0.019904  0.021501  0.023099
# RocketSuperAds             4251  0.034110  0.047283  0.053870  0.059280
# TipTop                    18498  0.056709  0.069413  0.076062  0.080711
# WahooNetBanner             8082  0.031180  0.038481  0.043306  0.045038
# YRabbit                    4102  0.025841  0.028766  0.031204  0.032179
# lambdaMediaAds             2056  0.072471  0.081712  0.085117  0.088521
#
#                          4.0       5.0       6.0       7.0       8.0  \
# channel
# AdNonSense          0.102107  0.103998  0.105348  0.105348  0.105889
# ...

# %% [markdown]
# Наблюдается очень низкая конверсия пользователей для каналов LeapBob, MediaTornado, OppleCreativeMedia и YRabbit. А лучшие показатели у каналов AdNonSense, FaceBoom и lambdaMediaAds.
#
# Изучим удержание пользователей.

# %%
retention_raw, retention_grouped, retention_history = get_retention(
    filtered_profiles, visits, observation_date, horizon_days, dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days, 14)

# %%
retention_grouped
# Out:
#                           cohort_size    0         1         2         3  \
# payer channel
# False AdNonSense                 3289  1.0  0.176345  0.087565  0.051079
#       FaceBoom                  24182  1.0  0.172980  0.087214  0.050782
#       LeapBob                    7860  1.0  0.171120  0.091349  0.051272
#       MediaTornado               4019  1.0  0.183130  0.082359  0.056482
#       OppleCreativeMedia         7919  1.0  0.171991  0.089026  0.053416
#       RocketSuperAds             3916  1.0  0.175179  0.085802  0.051328
#       TipTop                    16713  1.0  0.181715  0.084605  0.050859
#       WahooNetBanner             7654  1.0  0.184217  0.085446  0.053044
#       YRabbit                    3946  1.0  0.180182  0.083376  0.049164
#       lambdaMediaAds             1836  1.0  0.183007  0.086601  0.062636
# True  AdNonSense                  413  1.0  0.285714  0.162228  0.130751
#       FaceBoom                   3362  1.0  0.222487  0.123141  0.075253
# ...

# %% [markdown]
# Каналы AdNonSense и FaceBoom привлекают пользователей с самыми низкими показателями удержания. Остальные каналы по этому показателю близки друг другу.

# %% [markdown]
# Изучим какие каналы занимаются привлечением пользователей из каких стран.

# %%
filtered_profiles.pivot_table(index=['channel', 'region'], columns='payer', values='user_id', aggfunc='nunique')
# Out:
# payer                             False  True
# channel            region
# AdNonSense         France          1216   150
#                    Germany         1077   142
#                    UK              1147   148
# FaceBoom           United States  25587  3557
# LeapBob            France          2898    90
#                    Germany         2450    69
#                    UK              2943   103
# MediaTornado       United States   4208   156
# OppleCreativeMedia France          2911    80
#                    Germany         2498    64
#                    UK              2963    89
# RocketSuperAds     United States   4096   352
# TipTop             United States  17683  1878
# WahooNetBanner     France          2819   152
#                    Germany         2431   148
#                    UK              2850   153
# YRabbit            United States   4147   165
# lambdaMediaAds     France           660    82
#                    Germany          582    67
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# Проведенный анализ помог выявить, что:
# - реклама направленная на привлечение новых пользователей не оккупается;
# - пользователи из United States подвержены низкому удержанию, а с учетом того, что в привлечение этих пользователей вкладывается большое количество средств, это приводит к убыточности рекламы;
# - вложения в рекламу на привлечение европейских пользователей окупаются;
# - выявлены убыточные каналы, ими являются TipTop, FaceBoom и AdNonSense;
# - вложения в рекламу через канал TipTop необоснованно высокие, они в разы выше вложений в остальные каналы, и имеют тенденцию к росту, что также сказывается на общей окупаемости рекламы;
# - наиболее выгодным каналом для привлечения новых пользозавателей является lambdaMediaAds.
#
# Предложения по оптимизации маркетинга компании:
# - низкое удержание американских пользователей, возможно, связано с техническими проблемами серверов в United States, либо американцы не являются целевой аудиторией приложения. Требуется проанализировать причины и устранить их если, основой являются технические проблемы.
# - в случае, если американцы не являются целевой аудиторией, отказаться от каналов привлечения работающих только в United States, такие как FaceBoom, YRabbit, MediaTornado, TipTop и RocketSuperAds;
# - вложения в рекламу через канал TipTop необоснованно высокие, требуется отказаться от него;
# - также необходимо изучить почему такое низкое удержание у пользователей привлеченных с канала AdNonSense, причины могут крыться в привлекаемой аудитории этим каналом.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# 1. Мы прочитали и изучили получение данные по визитам пользователей приложения Procrastinate Pro+, их покупкам в данном прриложении, а также по тратам на рекламу для привлечения новых пользователей. В полученных данных отсутвуют дубликаты и пропуски. Мы привели названия столбцов к принятым стандартам и преобразовали к типу datetime данные о начале(session_start), конце сессий(session_end), к типу date дату рекламы(dt), а также о дате и времени покупки(event_dt).
# 2. Определили функции, которые помогут нам провести исследовательский анализ данных, рассчитать и визуализировать основные метрики.
# 3. Проанализировав профили пользователей, выявили:
#     - по полученным данным первый привлеченный с помощью рекламы пользователь воспользовался приложением 01.05.2019 г., а последнее привлечение произошло 27.10.2019 г;
#     - пользователи приложения Procrastinate Pro+ проживают в странах: United States, France, Germany и UK;
#     - следующие устройства используются для запуска приложения: Mac, iPhone, PC, Android;
#     - привлекали пользователей с помощью каналов: FaceBoom, AdNonSense, YRabbit, MediaTornado, RocketSuperAds, LeapBob, TipTop, WahooNetBanner, OppleCreativeMedia, lambdaMediaAds;
#     -  больше всего пользователей из United States и данные пользователи имеют самый высокий процент по конверсии в "платящих" пользователей 6.90%, тогда как меньше всего пользователей приложения из Germany при этом по соотношению они занимают вторую строчку с почти 4.11%. Самая низкая конвертация пользователей из France c 3.8%;
#     - большинство платящей аудитории пользуются продукцией Apple, а именно пользователи Iphone в количестве 3382 человек и пользователи Mac в количестве 1912 человек. Пользователи Mac занимают 3 место по количеству платящих пользователей, однако они на 1 месте по соотношению платящих ко всем пользователям данного устройства. Меньше всего конвертируются в платящих пользователи РС, всего 1537 человек и самая низкая конвертация в 5.05%. Пользователи Android с количеством 2050 платящих пользователей заняли вторую строку;
#     - выделяются два канала привлечения пользоватлей FaceBoom и TipTop, они приносят в разы больше пользователей чем остальные каналы. Восемь других других каналов не имеют такого сильного различия в количестве привлекаемых пользователей.
# 4. За период с 01.05.2019 г. по 27.10.2019 г. компания, для привлечения новых пользователей, вложила в рекламу 105 497.3 у.е.. Самые большие вложения в рекламные каналы TipTop и FaceBoom в размере 54 751.30 у.е. и 32 445.60 у.е. соответственно. TipTop также является и самым дорогим каналом для привлечения одного нового пользователя. А самыми дешевыми источниками оказались OppleCreativeMedia, MediaTornado, YRabbit и LeapBob с затратами на одного пользователя от 0.25 до 0.21 у.е..Засчет дорогих каналов привлечения, а именно TipTop и FaceBoom, средняя стоимость привлечения одного покупателя выросла до 1.13 у.е., это оказывает значительное воздействие на оккупаемость рекламы.Виден рост затрат от месяца к месяцу, а также после каждого роста вложений в рекламу идет спад, скорее всего после очередного увелечения рекламных затрат, компания их снижает и наблюдает на эффект от этих вложений, а затем продолжает вложения, возможно, уже в другие каналы.
# 5. Проведенный анализ помог выявить, что:
#     - реклама направленная на привлечение новых пользователей не оккупается;
#     - затраты на привлечение пользователей утройств Mac и Iphone, значительно выше остальных, скорее всего это связано с американским рынком, большое долей рынка этих устройств в United States;
#     - пользователи из United States подвержены низкому удержанию, а с учетом того, что в привлечение этих пользователей вкладывается большое количество средств, это приводит к убыточности рекламы;
#     - вложения в рекламу на привлечение европейских пользователей окупаются;
#     - выявлены убыточные каналы, ими являются TipTop, FaceBoom и AdNonSense;
#     - вложения в рекламу через канал TipTop необоснованно высокие, они в разы выше вложений в остальные каналы, и имеют тенденцию к росту, что также сказывается на общей окупаемости рекламы;
#     - наиболее выгодным каналом для привлечения новых пользозавателей является lambdaMediaAds.
#
# 6. Предложения по оптимизации маркетинга компании:
#     - низкое удержание американских пользователей, возможно, связано с техническими проблемами серверов в United States, либо американцы не являются целевой аудиторией приложения. Требуется проанализировать причины и устранить их если, основой являются технические проблемы;
#     - в случае, если американцы не являются целевой аудиторией, отказаться от каналов привлечения работающих только в United States, такие как FaceBoom, YRabbit, MediaTornado, TipTop и RocketSuperAds;
#     - вложения в рекламу через канал TipTop необоснованно высокие, требуется отказаться от него;
#     - также необходимо изучить почему такое низкое удержание у пользователей привлеченных с канала AdNonSense, причины могут крыться в привлекаемой аудитории этим каналом;
#     - для привлечения европейских пользователей лучше использовать каналы lambdaMediaAds и WahooNetBanner, увеличить привлечение новых клиентов с их участием;
#     - а для привлечения американской аудитории использовать каналы YRabbit и RocketSuperAds - это значительно сократит расходы на привлечение американских пользователей.
